# %% [markdown]
# # **1.Install Required Hugging Face Libraries:**
#
# This cell sets up key Hugging Face libraries`transformers`, `datasets`, and `peft` to enable efficient model usage, dataset handling, and lightweight fine-tuning, helping streamline workflows while minimizing resource consumption.

# %%
# !pip install -q transformers datasets
# !pip install -q git+https://github.com/huggingface/peft.git@main
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **2.Upgrade Pip and Install/Update Key Libraries:**
#
# This cell updates pip and installs or upgrades a suite of essential libraries needed for training, evaluating, and deploying speech recognition models.

# %%
# !pip install --upgrade pip
# !pip install --upgrade datasets[audio] transformers accelerate evaluate jiwer tensorboard gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 93.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 128.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
# ...

# %% [markdown]
# # **3.Install ASR and Fine-Tuning Dependencies:**
#
# This cell installs essential libraries for building and fine-tuning automatic speech recognition (ASR) models. It covers tools for loading audio, processing data, evaluating performance, and optimizing training efficiency across different hardware setups.

# %%
# !pip install transformers datasets torchaudio jiwer librosa
# !pip install accelerate
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 48.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **4.Load Dataset**

# %% [markdown]
# # **loads the essential libraries**
# This cell loads the essential libraries for reading, analyzing, manipulating, and playing back audio files within the notebook, along with tools for handling numerical and tabular data.

# %%
from IPython.display import Audio
from scipy.io import wavfile
import IPython.display as ipd
import librosa
import numpy as np
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd


#traing data
csv_path_train = "/content/drive/MyDrive/L2-KSU/ l2-ksu-train.csv"
df_train = pd.read_csv(csv_path_train, usecols=["text", "path"])  #  only the necessary column


#testing data
csv_path_test="/content/drive/MyDrive/L2-KSU/ l2-ksu-test.csv"
df_test = pd.read_csv(csv_path_test, usecols=["text", "path"])  #  only the necessary column


print(df_train.head())
# Out:
#                                     text  \
# 0          غير المغضوب عليهم ولا الضالين
# 1  وعد الله الذين آمنوا و عملوا الصالحات
# 2         قل أعوذ برب الفلق من شر ما خلق
# 3         قل أعوذ برب الفلق من شر ما خلق
# 4    الحمد لله رب العالمين الرحمن الرحيم
#
#                                                 path
# 0  /content/drive/MyDrive/L2-KSU/dataset/non-nati...
# 1  /content/drive/MyDrive/L2-KSU/dataset/native_s...
# 2  /content/drive/MyDrive/L2-KSU/dataset/native_s...
# 3  /content/drive/MyDrive/L2-KSU/dataset/native_s...
# 4  /content/drive/MyDrive/L2-KSU/dataset/native_s...

# %% [markdown]
# # **Load and Play an Audio Sample**

# %%
import IPython.display as ipd
import librosa

sample_index = 0
audio_path = df_train.iloc[sample_index]["path"]

# Load and play the audio file
speech_array, sr = librosa.load(audio_path, sr=16000)
ipd.Audio(speech_array, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Load and Play an Audio Sample**

# %%
sample_index = 100
audio_path = df_test.iloc[sample_index]["path"]

# Load and play the audio file
speech_array, sr = librosa.load(audio_path, sr=16000)
ipd.Audio(speech_array, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Check Existence of Audio File Paths:**
#
# This cell checks if specific audio files are present at their expected locations and prints whether each file exists, helping prevent file not found errors later in the pipeline.

# %%
import os

dataset_paths = [
  "/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/females/speaker19/sentence9/wav/Sp19_F_S9_5.wav"

]

for path in dataset_paths:
    if os.path.exists(path):
        print(f"File exists: {path}")
    else:
        print(f"File does not exist: {path}")
# Out:
# File exists: /content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/females/speaker19/sentence9/wav/Sp19_F_S9_5.wav

# %% [markdown]
# # **Plot Audio Waveform Using Matplotlib:**
# This cell generates a visual representation of the audio signal, allowing inspection of amplitude variations over time to better understand the characteristics of the spoken input.

# %%
import matplotlib.pyplot as plt

# Plot the waveform
plt.figure(figsize=(10, 4))
plt.plot(speech_array, color='blue')
plt.title("Waveform of the Audio Sample")
plt.xlabel("Time (samples)")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# # **Compute and Plot Audio Spectrogram:**
#
# This cell computes and displays the spectrogram of the audio signal, revealing its frequency components over time, which is useful for analyzing speech patterns and audio characteristics.

# %%
import librosa.display
import numpy as np

# Compute Short-Time Fourier Transform (STFT) for spectrogram
D = librosa.amplitude_to_db(np.abs(librosa.stft(speech_array)), ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=sr, x_axis="time", y_axis="log")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram of the Audio Sample")
plt.show()

# %% [markdown]
# # **Clear Unused GPU Memory**
# This cell clears any unused cached GPU memory to reduce memory pressure and help prevent out-of-memory errors during training or inference.

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # **Upgrade the Transformers Library:**
#
# This cell upgrades the transformers library to the latest version to ensure compatibility with the most recent models and features.

# %%
# !pip install --upgrade transformers

# %% [markdown]
# # **5.Prepare Feature Extractor, Tokenizer and Processor**

# %% [markdown]
# # **Import Libraries for Audio Processing and Wav2Vec2 Model:**
#
# This cell imports essential libraries for audio loading, preprocessing, and interaction with the Wav2Vec2 model, enabling end-to-end speech recognition from waveform to text.

# %%
import soundfile as sf
import librosa
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer ,Wav2Vec2Processor,Wav2Vec2FeatureExtractor

# %% [markdown]
# # **Specify Pretrained Arabic ASR Model Name:**
#
# This cell sets the path to a pretrained Wav2Vec2 model tailored for Arabic speech recognition, which will be loaded from the Hugging Face Model Hub.

# %%
model_name = "AndrewMcDowell/wav2vec2-xls-r-300m-arabic"

# %% [markdown]
# # **Load Pretrained Tokenizer**
#
# This cell loads the tokenizer tied to the Arabic Wav2Vec2 model, enabling conversion between model outputs and human-readable text.

# %%
tokenizer= Wav2Vec2Tokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/902 [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# ...

# %% [markdown]
# # **Define Feature Extractor and Load Pretrained Model:**
#
# This cell sets up the audio preprocessing pipeline and loads a pretrained Wav2Vec2 ASR model. The feature extractor prepares the raw audio, while the model converts it into transcribed text.

# %%
feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)
model = Wav2Vec2ForCTC.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/2.03k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]

# %% [markdown]
# # **Load Combined Processor (Tokenizer + Feature Extractor)**

# %%
processor = Wav2Vec2Processor.from_pretrained(model_name)
# Out:
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]

# %% [markdown]
# # Prepare Data

# %% [markdown]
# # **Create audio column from path column**

# %%
df_train['audio'] = df_train['path']

df_test['audio'] = df_test['path']

# %% [markdown]
# # **Convert DataFrames to Hugging Face Audio Datasets**
#
# This cell transforms the training and testing DataFrames into Hugging Face datasets with audio support, enabling proper loading and resampling of audio files for use with speech models.

# %%
from datasets import Dataset, Audio

# Convert training DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(df_train)
train_dataset = train_dataset.cast_column("audio", Audio(sampling_rate=16000))

# Convert testing DataFrame to Hugging Face Dataset
test_dataset = Dataset.from_pandas(df_test)
test_dataset = test_dataset.cast_column("audio", Audio(sampling_rate=16000))

# %%
# Verify the training dataset
print("Training Dataset info:")
print(train_dataset)
print("\nFirst training example:")
print(train_dataset[0])
# Out:
# Training Dataset info:
# Dataset({
#     features: ['text', 'path', 'audio'],
#     num_rows: 3273
# })
#
# First training example:
# {'text': 'غير المغضوب عليهم ولا الضالين', 'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/females/speaker19/sentence4/wav/Sp19_F_S4_4.wav', 'audio': {'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/females/speaker19/sentence4/wav/Sp19_F_S4_4.wav', 'array': array([-0.00305176, -0.00262451, -0.00228882, ...,  0.00018311,
#         0.00030518, -0.0005188 ]), 'sampling_rate': 16000}}

# %%
# Verify the testing dataset
print("Testing Dataset info:")
print(test_dataset)
print("\nFirst testing example:")
print(test_dataset[0])
# Out:
# Testing Dataset info:
# Dataset({
#     features: ['text', 'path', 'audio'],
#     num_rows: 813
# })
#
# First testing example:
# {'text': 'صلى الله على نبينا محمد و على آله و صحبه أجمعين', 'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/males/speaker2/sentence9/wav/Sp2_M_S9_2.wav', 'audio': {'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/males/speaker2/sentence9/wav/Sp2_M_S9_2.wav', 'array': array([ 0.02282715,  0.02258301,  0.02236938, ..., -0.0032959 ,
#        -0.00341797, -0.00363159]), 'sampling_rate': 16000}}

# %%
print(train_dataset[0])
# Out:
# {'text': 'غير المغضوب عليهم ولا الضالين', 'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/females/speaker19/sentence4/wav/Sp19_F_S4_4.wav', 'audio': {'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/females/speaker19/sentence4/wav/Sp19_F_S4_4.wav', 'array': array([-0.00305176, -0.00262451, -0.00228882, ...,  0.00018311,
#         0.00030518, -0.0005188 ]), 'sampling_rate': 16000}}

# %%
print(test_dataset[0])
# Out:
# {'text': 'صلى الله على نبينا محمد و على آله و صحبه أجمعين', 'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/males/speaker2/sentence9/wav/Sp2_M_S9_2.wav', 'audio': {'path': '/content/drive/MyDrive/L2-KSU/dataset/non-native_speakers/males/speaker2/sentence9/wav/Sp2_M_S9_2.wav', 'array': array([ 0.02282715,  0.02258301,  0.02236938, ..., -0.0032959 ,
#        -0.00341797, -0.00363159]), 'sampling_rate': 16000}}

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(train_dataset)-1)

# Access the 'text' column instead of 'sentence'
print(train_dataset[rand_int]["text"])
ipd.Audio(data=train_dataset[rand_int]["audio"]["array"], autoplay=True, rate=16000)
# Out:
# صلى الله على نبينا محمد و على آله و أصحابه أجمعين
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_int = random.randint(0, len(train_dataset)-1)

print("Target text:", train_dataset[rand_int]["text"])
print("Input array shape:", train_dataset[rand_int]["audio"]["array"].shape)
print("Sampling rate:",train_dataset[rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: قل أعوذ برب الفلق من شر ما خلق
# Input array shape: (73202,)
# Sampling rate: 16000

# %% [markdown]
# # **Define Function to Prepare Dataset for Model Input:**
# This function converts raw audio and transcription text into model-ready inputs and labels, using the processor to handle feature extraction and tokenization for speech recognition training.

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched"
    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    batch["input_length"] = len(batch["input_values"])

    # Ensure 'text' is a string by explicitly converting it
    with processor.as_target_processor():
        batch["labels"] = processor(str(batch["text"])).input_ids
    return batch

# %% [markdown]
# # **Apply Preprocessing to the Dataset**

# %%
train_dataset = train_dataset.map(prepare_dataset, remove_columns=train_dataset.column_names)
test_dataset = test_dataset.map(prepare_dataset, remove_columns=test_dataset.column_names)
# Out:
# Map:   0%|          | 0/3273 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:174: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/813 [00:00<?, ? examples/s]

# %% [markdown]
# # **Check Processed Dataset Structure**

# %%
# Verify the processed training dataset structure
print("Training Dataset features after processing:")
print(train_dataset.features)
# Out:
# Training Dataset features after processing:
# {'input_values': Sequence(feature=Value(dtype='float32', id=None), length=-1, id=None), 'input_length': Value(dtype='int64', id=None), 'labels': Sequence(feature=Value(dtype='int64', id=None), length=-1, id=None)}

# %%
# Verify the processed training dataset structure
print("Training Dataset features after processing:")
print(test_dataset.features)
# Out:
# Training Dataset features after processing:
# {'input_values': Sequence(feature=Value(dtype='float32', id=None), length=-1, id=None), 'input_length': Value(dtype='int64', id=None), 'labels': Sequence(feature=Value(dtype='int64', id=None), length=-1, id=None)}

# %% [markdown]
# # Training

# %% [markdown]
# # **Define Custom Data Collator for CTC with Dynamic Padding**
# This cell defines a custom collator that pads audio inputs and transcription labels separately for CTC-based models, replacing label padding with -100 to ensure proper loss computation during training.

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %% [markdown]
# # **Initialize Custom Data Collator for CTC**
#
# This cell initializes the custom data collator that ensures audio and label sequences are padded correctly during training with the Wav2Vec2 model.

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# # **Install Evaluation Library**
#
# This cell installs the evaluate library, which provides standardized tools for computing performance metrics like Word Error Rate (WER) in speech recognition tasks.

# %%
# !pip install evaluate

# %% [markdown]
# # **Load Word Error Rate (WER) Evaluation Metric**

# %%
import evaluate
wer_metric = evaluate.load("wer")

# %% [markdown]
# # **Define Metric Computation Function (WER)**
#
#
# This function decodes model predictions and reference labels into text, then computes the Word Error Rate (WER) to evaluate speech recognition accuracy.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# # **Load Pretrained Wav2Vec2 Model for CTC**
#
# This cell loads the Wav2Vec2 XLS-R 300M model with a CTC head and configures it for Arabic ASR by aligning it with the tokenizer’s vocabulary and disabling regularization for fine-tuning or evaluation.

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-xls-r-300m",
    attention_dropout=0.0,
    hidden_dropout=0.0,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.0,
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer),
)
# Out:
# config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-xls-r-300m and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # **Freeze Feature Encoder:**
# This line freezes the model’s feature extraction layers to retain pre-learned audio representations and reduce training complexity during fine-tuning.

# %%
model.freeze_feature_encoder()

# %% [markdown]
# # **Authenticate with Hugging Face Hub**

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !apt install git-lfs
# Out:
# model.safetensors:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
repo_name = "AAK1423/wave2vec"

# %%
from huggingface_hub import login
login(token="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")

# %%
tokenizer.push_to_hub(repo_name)
# Out:
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/AAK1423/wave2vec/commit/274c58a706980ab4fc1331ec715b8e8d72210d65', commit_message='Upload tokenizer', commit_description='', oid='274c58a706980ab4fc1331ec715b8e8d72210d65', pr_url=None, repo_url=RepoUrl('https://huggingface.co/AAK1423/wave2vec', endpoint='https://huggingface.co', repo_type='model', repo_id='AAK1423/wave2vec'), pr_revision=None, pr_num=None)

# %% [markdown]
# # **Define Training Configuration**
#
# This cell configures the training process by setting batch size, learning rate, epochs, precision mode, evaluation frequency, and saving behavior, while also enabling hub integration for model sharing.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir=repo_name,
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=30,
  gradient_checkpointing=True,
  fp16=True,
  save_steps=400,
  eval_steps=400,
  logging_steps=400,
  learning_rate=3e-4,
  warmup_steps=500,
  save_total_limit=2,
  push_to_hub=True,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# # **Initialize Hugging Face Trainer**

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=processor.feature_extractor,
)
# Out:
# <ipython-input-47-de28a347269f>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
import wandb
wandb.init(project="w2v_finetuning")
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: leyla95three (leyla95three-computer-engineering-department-college-of-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/content/wandb/run-20250215_170645-jd8vb459</code>
# ...

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2401' max='3060' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2401/3060 2:36:47 < 43:04, 0.26 it/s, Epoch 23.30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>400</td>
#       <td>0.322000</td>
#       <td>0.151078</td>
#       <td>0.134965</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.065800</td>
#       <td>0.098989</td>
#       <td>0.093623</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.024800</td>
#       <td>0.070705</td>
#       <td>0.086763</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.013500</td>
#       <td>0.041115</td>
#       <td>0.040971</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.007400</td>
# ...

# %%
trainer.push_to_hub()
# Out:
# CommitInfo(commit_url='https://huggingface.co/AAK1423/wave2vec/commit/d3a690d4b14645eefdc37b670af9bb608e78d7f0', commit_message='End of training', commit_description='', oid='d3a690d4b14645eefdc37b670af9bb608e78d7f0', pr_url=None, repo_url=RepoUrl('https://huggingface.co/AAK1423/wave2vec', endpoint='https://huggingface.co', repo_type='model', repo_id='AAK1423/wave2vec'), pr_revision=None, pr_num=None)

# %% [markdown]
# # Evaluation

# %%
test_metrics = trainer.evaluate()
print("\nInitial evaluation metrics:")
print(f"WER (Word Error Rate): {test_metrics['eval_wer']:.4f}")
print(f"Loss: {test_metrics['eval_loss']:.4f}")

for key, value in test_metrics.items():
    if key not in ['eval_wer', 'eval_loss']:
        print(f"{key}: {value:.4f}")
# Out:
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# /usr/local/lib/python3.11/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:174: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 01:02]
#     </div>
# Initial evaluation metrics:
# WER (Word Error Rate): 0.0252
# Loss: 0.0230
# eval_runtime: 65.6648
# eval_samples_per_second: 12.3810
# eval_steps_per_second: 1.5530
# epoch: 29.7122

# %%
trainer.save_model("w2v_model")
# Out:
# events.out.tfevents.1739652822.c2d0b0d85fff.1145.1:   0%|          | 0.00/406 [00:00<?, ?B/s]
